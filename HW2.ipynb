# %% [markdown]
# Pseudocode

# %%
Head east
while not on Shida Rd:
    walk 1 meter
turn right
while not on Lane 39, Shida Rd:
    walk 1 meter
turn left
while not at Shida Night Market:
    walk 1 meter
stop

# %% [markdown]
# ![Blank diagram.png](data:image/png;base64,...)
